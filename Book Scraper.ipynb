# %% [markdown]
# ## Import libraries

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in /Users/gaayatripradeep/anaconda3/lib/python3.11/site-packages (2.29.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/gaayatripradeep/anaconda3/lib/python3.11/site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/gaayatripradeep/anaconda3/lib/python3.11/site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/gaayatripradeep/anaconda3/lib/python3.11/site-packages (from requests) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/gaayatripradeep/anaconda3/lib/python3.11/site-packages (from requests) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in /Users/gaayatripradeep/anaconda3/lib/python3.11/site-packages (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in /Users/gaayatripradeep/anaconda3/lib/python3.11/site-packages (from beautifulsoup4) (2.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup
import csv
import pandas as pd
import time

# %% [markdown]
# ## Get URL and send GET request

# %%
url = "https://books.toscrape.com/"
response = requests.get(url)

# %%
if response.status_code == 200:
    print("Request Successful")
else:
    print("Request Failed")
# Out:
# Request Successful

# %% [markdown]
# ## Parse HTML Content

# %%
soup = BeautifulSoup(response.text,"html.parser")

# %% [markdown]
# ## Extract Book Details from Page 1

# %%
#Find all h3 tags because within the h3 tag is the anchor element which contains the link to the page with the book info
books = soup.find_all('h3')
#find_all will return all matching elements in a list

start_time = time.time()
books_extracted = 0

#Iterate through the books and extract information for each book
for book in books:
    book_url = book.find('a')['href'] #extract href from the first anchor element
    book_response = requests.get(url+book_url)
    book_soup = BeautifulSoup(book_response.content,"html.parser")#Create new object which will return the info from that url
    
    title = book_soup.find('h1').text
    category = book_soup.find('ul',class_ = "breadcrumb").find_all('a')[2].text.strip()#class is mentioned as class_ as class is a keyword in python, to not confuse the compiler
    rating = book_soup.find('p',class_ = 'star-rating')['class'][1]
    price = book_soup.find('p',class_='price_color').text.strip()
    availability = book_soup.find('p',class_='availability').text.strip()
    
    books_extracted +=1
    
    end_time = time.time()
    total_time = (end_time - start_time)/60.0
    
    print(f'Title: {title}')
    print(f'Category: {category}')
    print(f'Rating: {rating}')
    print(f'Price: {price}')
    print(f'Availability: {availability}')
    print('***********')
# Out:
# Title: A Light in the Attic
# Category: Poetry
# Rating: Three
# Price: £51.77
# Availability: In stock (22 available)
# ***********
# Title: Tipping the Velvet
# Category: Historical Fiction
# Rating: One
# Price: £53.74
# Availability: In stock (20 available)
# ***********
# Title: Soumission
# Category: Fiction
# Rating: One
# Price: £50.10
# Availability: In stock (20 available)
# ***********
# Title: Sharp Objects
# Category: Mystery
# Rating: Four
# Price: £47.82
# Availability: In stock (20 available)
# ***********
# Title: Sapiens: A Brief History of Humankind
# Category: History
# Rating: Five
# Price: £54.23
# Availability: In stock (20 available)
# ***********
# Title: The Requiem Red
# Category: Young Adult
# Rating: One
# Price: £22.65
# Availability: In stock (19 available)
# ***********
# Title: The Dirty Little Secrets of Getting Your Dream Job
# Category: Business
# Rating: Four
# Price: £33.34
# Availability: In stock (19 available)
# ***********
# Title: The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull
# Category: Default
# Rating: Three
# Price: £17.93
# Availability: In stock (19 available)
# ***********
# Title: The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics
# Category: Default
# Rating: Four
# Price: £22.60
# Availability: In stock (19 available)
# ***********
# Title: The Black Maria
# Category: Poetry
# Rating: One
# Price: £52.15
# Availability: In stock (19 available)
# ***********
# Title: Starving Hearts (Triangular Trade Trilogy, #1)
# Category: Default
# Rating: Two
# Price: £13.99
# Availability: In stock (19 available)
# ***********
# Title: Shakespeare's Sonnets
# Category: Poetry
# Rating: Four
# Price: £20.66
# Availability: In stock (19 available)
# ***********
# Title: Set Me Free
# Category: Young Adult
# Rating: Five
# Price: £17.46
# Availability: In stock (19 available)
# ***********
# Title: Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)
# Category: Sequential Art
# Rating: Five
# Price: £52.29
# Availability: In stock (19 available)
# ***********
# Title: Rip it Up and Start Again
# Category: Music
# Rating: Five
# Price: £35.02
# Availability: In stock (19 available)
# ***********
# Title: Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991
# Category: Music
# Rating: Three
# Price: £57.25
# Availability: In stock (19 available)
# ***********
# Title: Olio
# Category: Poetry
# Rating: One
# Price: £23.88
# Availability: In stock (19 available)
# ***********
# Title: Mesaerion: The Best Science Fiction Stories 1800-1849
# Category: Science Fiction
# Rating: One
# Price: £37.59
# Availability: In stock (19 available)
# ***********
# Title: Libertarianism for Beginners
# Category: Politics
# Rating: Two
# Price: £51.33
# Availability: In stock (19 available)
# ***********
# Title: It's Only the Himalayas
# Category: Travel
# Rating: Two
# Price: £45.17
# Availability: In stock (19 available)
# ***********

# %% [markdown]
# ## Extract Data for all 50 pages

# %%
import requests
from bs4 import BeautifulSoup
import time

# Create a list to hold all the book information
books_data = []

# Loop through all 50 pages
for page_num in range(1, 51):
    url = f'https://books.toscrape.com/catalogue/page-{page_num}.html'
    response = requests.get(url)
    soup = BeautifulSoup(response.content, "html.parser")
    
    start_time = time.time()
    books_extracted = 0

    # Extract book elements
    books = soup.find_all('h3')
    
    for book in books:
        book_url = book.find('a')['href']
        book_url = 'https://books.toscrape.com/catalogue/' + book_url
        
        book_response = requests.get(book_url)
        book_soup = BeautifulSoup(book_response.content, "html.parser")
        
        title = book_soup.find('h1').text
        category = book_soup.find('ul', class_="breadcrumb").find_all('a')[2].text.strip()
        rating = book_soup.find('p', class_='star-rating')['class'][1]
        price = book_soup.find('p', class_='price_color').text.strip()
        availability = book_soup.find('p', class_='availability').text.strip()
        
        books_extracted += 1
        end_time = time.time()
        total_time = (end_time - start_time) / 60.0
        
        books_data.append([title, category, rating, price, availability])
        print(books_data[-1])  # Print the latest book data
        print('*******')

print(f"Total books extracted: {len(books_data)}")
# Out:
# ['A Light in the Attic', 'Poetry', 'Three', '£51.77', 'In stock (22 available)']
# *******
# ['Tipping the Velvet', 'Historical Fiction', 'One', '£53.74', 'In stock (20 available)']
# *******
# ['Soumission', 'Fiction', 'One', '£50.10', 'In stock (20 available)']
# *******
# ['Sharp Objects', 'Mystery', 'Four', '£47.82', 'In stock (20 available)']
# *******
# ['Sapiens: A Brief History of Humankind', 'History', 'Five', '£54.23', 'In stock (20 available)']
# *******
# ['The Requiem Red', 'Young Adult', 'One', '£22.65', 'In stock (19 available)']
# *******
# ['The Dirty Little Secrets of Getting Your Dream Job', 'Business', 'Four', '£33.34', 'In stock (19 available)']
# *******
# ['The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull', 'Default', 'Three', '£17.93', 'In stock (19 available)']
# *******
# ['The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics', 'Default', 'Four', '£22.60', 'In stock (19 available)']
# *******
# ['The Black Maria', 'Poetry', 'One', '£52.15', 'In stock (19 available)']
# *******
# ['Starving Hearts (Triangular Trade Trilogy, #1)', 'Default', 'Two', '£13.99', 'In stock (19 available)']
# *******
# ["Shakespeare's Sonnets", 'Poetry', 'Four', '£20.66', 'In stock (19 available)']
# *******
# ['Set Me Free', 'Young Adult', 'Five', '£17.46', 'In stock (19 available)']
# *******
# ["Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)", 'Sequential Art', 'Five', '£52.29', 'In stock (19 available)']
# *******
# ['Rip it Up and Start Again', 'Music', 'Five', '£35.02', 'In stock (19 available)']
# *******
# ['Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991', 'Music', 'Three', '£57.25', 'In stock (19 available)']
# *******
# ['Olio', 'Poetry', 'One', '£23.88', 'In stock (19 available)']
# *******
# ['Mesaerion: The Best Science Fiction Stories 1800-1849', 'Science Fiction', 'One', '£37.59', 'In stock (19 available)']
# *******
# ['Libertarianism for Beginners', 'Politics', 'Two', '£51.33', 'In stock (19 available)']
# *******
# ["It's Only the Himalayas", 'Travel', 'Two', '£45.17', 'In stock (19 available)']
# *******
# ['In Her Wake', 'Thriller', 'One', '£12.84', 'In stock (19 available)']
# *******
# ['How Music Works', 'Music', 'Two', '£37.32', 'In stock (19 available)']
# *******
# ['Foolproof Preserving: A Guide to Small Batch Jams, Jellies, Pickles, Condiments, and More: A Foolproof Guide to Making Small Batch Jams, Jellies, Pickles, Condiments, and More', 'Food and Drink', 'Three', '£30.52', 'In stock (19 available)']
# *******
# ['Chase Me (Paris Nights #2)', 'Romance', 'Five', '£25.27', 'In stock (19 available)']
# *******
# ['Black Dust', 'Romance', 'Five', '£34.53', 'In stock (19 available)']
# *******
# ['Birdsong: A Story in Pictures', 'Childrens', 'Three', '£54.64', 'In stock (19 available)']
# *******
# ["America's Cradle of Quarterbacks: Western Pennsylvania's Football Factory from Johnny Unitas to Joe Montana", 'Default', 'Three', '£22.50', 'In stock (19 available)']
# *******
# ['Aladdin and His Wonderful Lamp', 'Default', 'Three', '£53.13', 'In stock (19 available)']
# *******
# ['Worlds Elsewhere: Journeys Around Shakespeare’s Globe', 'Nonfiction', 'Five', '£40.30', 'In stock (18 available)']
# *******
# ['Wall and Piece', 'Art', 'Four', '£44.18', 'In stock (18 available)']
# *******
# ['The Four Agreements: A Practical Guide to Personal Freedom', 'Spirituality', 'Five', '£17.66', 'In stock (18 available)']
# *******
# ['The Five Love Languages: How to Express Heartfelt Commitment to Your Mate', 'Nonfiction', 'Three', '£31.05', 'In stock (18 available)']
# *******
# ['The Elephant Tree', 'Thriller', 'Five', '£23.82', 'In stock (18 available)']
# *******
# ['The Bear and the Piano', 'Childrens', 'One', '£36.89', 'In stock (18 available)']
# *******
# ["Sophie's World", 'Philosophy', 'Five', '£15.94', 'In stock (18 available)']
# *******
# ['Penny Maybe', 'Default', 'Three', '£33.29', 'In stock (18 available)']
# *******
# ['Maude (1883-1993):She Grew Up with the country', 'Default', 'Two', '£18.02', 'In stock (18 available)']
# *******
# ['In a Dark, Dark Wood', 'Mystery', 'One', '£19.63', 'In stock (18 available)']
# *******
# ['Behind Closed Doors', 'Thriller', 'Four', '£52.22', 'In stock (18 available)']
# *******
# ["You can't bury them all: Poems", 'Poetry', 'Two', '£33.63', 'In stock (17 available)']
# *******
# ['Slow States of Collapse: Poems', 'Poetry', 'Three', '£57.31', 'In stock (17 available)']
# *******
# ['Reasons to Stay Alive', 'Nonfiction', 'Two', '£26.41', 'In stock (17 available)']
# *******
# ['Private Paris (Private #10)', 'Fiction', 'Five', '£47.61', 'In stock (17 available)']
# *******
# ['#HigherSelfie: Wake Up Your Life. Free Your Soul. Find Your Tribe.', 'Nonfiction', 'Five', '£23.11', 'In stock (17 available)']
# *******
# ['Without Borders (Wanderlove #1)', 'New Adult', 'Two', '£45.07', 'In stock (16 available)']
# *******
# ['When We Collided', 'Contemporary', 'One', '£31.77', 'In stock (16 available)']
# *******
# ['We Love You, Charlie Freeman', 'Fiction', 'Five', '£50.27', 'In stock (16 available)']
# *******
# ['Untitled Collection: Sabbath Poems 2014', 'Poetry', 'Four', '£14.27', 'In stock (16 available)']
# *******
# ['Unseen City: The Majesty of Pigeons, the Discreet Charm of Snails & Other Wonders of the Urban Wilderness', 'Nonfiction', 'Four', '£44.18', 'In stock (16 available)']
# *******
# ['Unicorn Tracks', 'Fantasy', 'Three', '£18.78', 'In stock (16 available)']
# *******
# ['Unbound: How Eight Technologies Made Us Human, Transformed Society, and Brought Our World to the Brink', 'History', 'One', '£25.52', 'In stock (16 available)']
# *******
# ['Tsubasa: WoRLD CHRoNiCLE 2 (Tsubasa WoRLD CHRoNiCLE #2)', 'Sequential Art', 'One', '£16.28', 'In stock (16 available)']
# *******
# ['Throwing Rocks at the Google Bus: How Growth Became the Enemy of Prosperity', 'Nonfiction', 'Three', '£31.12', 'In stock (16 available)']
# *******
# ['This One Summer', 'Sequential Art', 'Four', '£19.49', 'In stock (16 available)']
# *******
# ['Thirst', 'Fiction', 'Five', '£17.27', 'In stock (16 available)']
# *******
# ['The Torch Is Passed: A Harding Family Story', 'Add a comment', 'One', '£19.09', 'In stock (16 available)']
# *******
# ['The Secret of Dreadwillow Carse', 'Childrens', 'One', '£56.13', 'In stock (16 available)']
# *******
# ['The Pioneer Woman Cooks: Dinnertime: Comfort Classics, Freezer Food, 16-Minute Meals, and Other Delicious Ways to Solve Supper!', 'Food and Drink', 'One', '£56.41', 'In stock (16 available)']
# *******
# ['The Past Never Ends', 'Mystery', 'Four', '£56.50', 'In stock (16 available)']
# *******
# ['The Natural History of Us (The Fine Art of Pretending #2)', 'Young Adult', 'Three', '£45.22', 'In stock (16 available)']
# *******
# ['The Nameless City (The Nameless City #1)', 'Sequential Art', 'Four', '£38.16', 'In stock (16 available)']
# *******
# ['The Murder That Never Was (Forensic Instincts #5)', 'Fiction', 'Three', '£54.11', 'In stock (16 available)']
# *******
# ["The Most Perfect Thing: Inside (and Outside) a Bird's Egg", 'Science', 'Four', '£42.96', 'In stock (16 available)']
# *******
# ['The Mindfulness and Acceptance Workbook for Anxiety: A Guide to Breaking Free from Anxiety, Phobias, and Worry Using Acceptance and Commitment Therapy', 'Add a comment', 'Four', '£23.89', 'In stock (16 available)']
# *******
# ['The Life-Changing Magic of Tidying Up: The Japanese Art of Decluttering and Organizing', 'Nonfiction', 'Three', '£16.77', 'In stock (16 available)']
# *******
# ['The Inefficiency Assassin: Time Management Tactics for Working Smarter, Not Longer', 'Default', 'Five', '£20.59', 'In stock (16 available)']
# *******
# ['The Gutsy Girl: Escapades for Your Life of Epic Adventure', 'Nonfiction', 'One', '£37.13', 'In stock (16 available)']
# *******
# ['The Electric Pencil: Drawings from Inside State Hospital No. 3', 'Nonfiction', 'One', '£56.06', 'In stock (16 available)']
# *******
# ['The Death of Humanity: and the Case for Life', 'Philosophy', 'Four', '£58.11', 'In stock (16 available)']
# *******
# ['The Bulletproof Diet: Lose up to a Pound a Day, Reclaim Energy and Focus, Upgrade Your Life', 'Health', 'Three', '£49.05', 'In stock (16 available)']
# *******
# ['The Art Forger', 'Add a comment', 'Three', '£40.76', 'In stock (16 available)']
# *******
# ['The Age of Genius: The Seventeenth Century and the Birth of the Modern Mind', 'History', 'One', '£19.73', 'In stock (16 available)']
# *******
# ["The Activist's Tao Te Ching: Ancient Advice for a Modern Revolution", 'Spirituality', 'Five', '£32.24', 'In stock (16 available)']
# *******
# ['Spark Joy: An Illustrated Master Class on the Art of Organizing and Tidying Up', 'Nonfiction', 'Four', '£41.83', 'In stock (16 available)']
# *******
# ['Soul Reader', 'Default', 'Two', '£39.58', 'In stock (16 available)']
# *******
# ['Security', 'Horror', 'Two', '£39.25', 'In stock (16 available)']
# *******
# ['Saga, Volume 6 (Saga (Collected Editions) #6)', 'Fantasy', 'Three', '£25.02', 'In stock (16 available)']
# *******
# ['Saga, Volume 5 (Saga (Collected Editions) #5)', 'Sequential Art', 'Two', '£51.04', 'In stock (16 available)']
# *******
# ['Reskilling America: Learning to Labor in the Twenty-First Century', 'Nonfiction', 'Two', '£19.83', 'In stock (16 available)']
# *******
# ['Rat Queens, Vol. 3: Demons (Rat Queens (Collected Editions) #11-15)', 'Sequential Art', 'Three', '£50.40', 'In stock (16 available)']
# *******
# ['Princess Jellyfish 2-in-1 Omnibus, Vol. 01 (Princess Jellyfish 2-in-1 Omnibus #1)', 'Sequential Art', 'Five', '£13.61', 'In stock (16 available)']
# *******
# ['Princess Between Worlds (Wide-Awake Princess #5)', 'Fantasy', 'Five', '£13.34', 'In stock (16 available)']
# *******
# ['Pop Gun War, Volume 1: Gift', 'Sequential Art', 'One', '£18.97', 'In stock (16 available)']
# *******
# ['Political Suicide: Missteps, Peccadilloes, Bad Calls, Backroom Hijinx, Sordid Pasts, Rotten Breaks, and Just Plain Dumb Mistakes in the Annals of American Politics', 'History', 'Two', '£36.28', 'In stock (16 available)']
# *******
# ['Patience', 'Sequential Art', 'Three', '£10.16', 'In stock (16 available)']
# *******
# ['Outcast, Vol. 1: A Darkness Surrounds Him (Outcast #1)', 'Sequential Art', 'Four', '£15.44', 'In stock (16 available)']
# *******
# ['orange: The Complete Collection 1 (orange: The Complete Collection #1)', 'Sequential Art', 'One', '£48.41', 'In stock (16 available)']
# *******
# ['Online Marketing for Busy Authors: A Step-By-Step Guide', 'Self Help', 'One', '£46.35', 'In stock (16 available)']
# *******
# ['On a Midnight Clear', 'Add a comment', 'Three', '£14.07', 'In stock (16 available)']
# *******
# ['Obsidian (Lux #1)', 'Young Adult', 'Two', '£14.86', 'In stock (16 available)']
# *******
# ['My Paris Kitchen: Recipes and Stories', 'Food and Drink', 'Two', '£33.37', 'In stock (16 available)']
# *******
# ['Masks and Shadows', 'Fantasy', 'Two', '£56.40', 'In stock (16 available)']
# *******
# ['Mama Tried: Traditional Italian Cooking for the Screwed, Crude, Vegan, and Tattooed', 'Food and Drink', 'Four', '£14.02', 'In stock (16 available)']
# *******
# ['Lumberjanes, Vol. 2: Friendship to the Max (Lumberjanes #5-8)', 'Sequential Art', 'Two', '£46.91', 'In stock (16 available)']
# *******
# ['Lumberjanes, Vol. 1: Beware the Kitten Holy (Lumberjanes #1-4)', 'Sequential Art', 'Three', '£45.61', 'In stock (16 available)']
# *******
# ['Lumberjanes Vol. 3: A Terrible Plan (Lumberjanes #9-12)', 'Sequential Art', 'Two', '£19.92', 'In stock (16 available)']
# *******
# ['Layered: Baking, Building, and Styling Spectacular Cakes', 'Food and Drink', 'One', '£40.11', 'In stock (16 available)']
# *******
# ['Judo: Seven Steps to Black Belt (an Introductory Guide for Beginners)', 'Add a comment', 'Two', '£53.90', 'In stock (16 available)']
# *******
# ['Join', 'Science Fiction', 'Five', '£35.67', 'In stock (16 available)']
# *******
# ['In the Country We Love: My Family Divided', 'Nonfiction', 'Four', '£22.00', 'In stock (16 available)']
# *******
# ['Immunity: How Elie Metchnikoff Changed the Course of Modern Medicine', 'Science', 'Five', '£57.36', 'In stock (16 available)']
# *******
# ['I Hate Fairyland, Vol. 1: Madly Ever After (I Hate Fairyland (Compilations) #1-5)', 'Sequential Art', 'Two', '£29.17', 'In stock (16 available)']
# *******
# ['I am a Hero Omnibus Volume 1', 'Sequential Art', 'Three', '£54.63', 'In stock (16 available)']
# *******
# ['How to Be Miserable: 40 Strategies You Already Use', 'Self Help', 'One', '£46.03', 'In stock (16 available)']
# *******
# ['Her Backup Boyfriend (The Sorensen Family #1)', 'Romance', 'One', '£33.97', 'In stock (16 available)']
# *******
# ['Giant Days, Vol. 2 (Giant Days #5-8)', 'Sequential Art', 'Two', '£22.11', 'In stock (16 available)']
# *******
# ['Forever and Forever: The Courtship of Henry Longfellow and Fanny Appleton', 'Historical Fiction', 'Three', '£29.69', 'In stock (16 available)']
# *******
# ['First and First (Five Boroughs #3)', 'Romance', 'Four', '£15.97', 'In stock (16 available)']
# *******
# ['Fifty Shades Darker (Fifty Shades #2)', 'Romance', 'One', '£21.96', 'In stock (16 available)']
# *******
# ['Everydata: The Misinformation Hidden in the Little Data You Consume Every Day', 'Nonfiction', 'Two', '£54.35', 'In stock (16 available)']
# *******
# ["Don't Be a Jerk: And Other Practical Advice from Dogen, Japan's Greatest Zen Master", 'Religion', 'Two', '£37.97', 'In stock (16 available)']
# *******
# ['Danganronpa Volume 1', 'Sequential Art', 'Four', '£51.99', 'In stock (16 available)']
# *******
# ['Crown of Midnight (Throne of Glass #2)', 'Fantasy', 'Three', '£43.29', 'In stock (16 available)']
# *******
# ['Codename Baboushka, Volume 1: The Conclave of Death', 'Sequential Art', 'Four', '£36.72', 'In stock (16 available)']
# *******
# ['Camp Midnight', 'Sequential Art', 'Four', '£17.08', 'In stock (16 available)']
# *******
# ['Call the Nurse: True Stories of a Country Nurse on a Scottish Isle', 'Nonfiction', 'Five', '£29.14', 'In stock (16 available)']
# *******
# ['Burning', 'Young Adult', 'Three', '£28.81', 'In stock (16 available)']
# *******
# ['Bossypants', 'Default', 'Two', '£49.46', 'In stock (16 available)']
# *******
# ['Bitch Planet, Vol. 1: Extraordinary Machine (Bitch Planet (Collected Editions))', 'Sequential Art', 'Two', '£37.92', 'In stock (16 available)']
# *******
# ['Avatar: The Last Airbender: Smoke and Shadow, Part 3 (Smoke and Shadow #3)', 'Fantasy', 'Two', '£28.09', 'In stock (16 available)']
# *******
# ['Algorithms to Live By: The Computer Science of Human Decisions', 'Nonfiction', 'One', '£30.81', 'In stock (16 available)']
# *******
# ['A World of Flavor: Your Gluten Free Passport', 'Default', 'One', '£42.95', 'In stock (16 available)']
# *******
# ['A Piece of Sky, a Grain of Rice: A Memoir in Four Meditations', 'Default', 'Five', '£56.76', 'In stock (16 available)']
# *******
# ['A Murder in Time', 'Mystery', 'One', '£16.64', 'In stock (16 available)']
# *******
# ['A Flight of Arrows (The Pathfinders #2)', 'Historical Fiction', 'Five', '£55.53', 'In stock (16 available)']
# *******
# ['A Fierce and Subtle Poison', 'Young Adult', 'Four', '£28.13', 'In stock (16 available)']
# *******
# ['A Court of Thorns and Roses (A Court of Thorns and Roses #1)', 'Fantasy', 'One', '£52.37', 'In stock (16 available)']
# *******
# ['(Un)Qualified: How God Uses Broken People to Do Big Things', 'Christian', 'Five', '£54.00', 'In stock (16 available)']
# *******
# ['You Are What You Love: The Spiritual Power of Habit', 'Religion', 'Four', '£21.87', 'In stock (15 available)']
# *******
# ["William Shakespeare's Star Wars: Verily, A New Hope (William Shakespeare's Star Wars #4)", 'Science Fiction', 'Four', '£43.30', 'In stock (15 available)']
# *******
# ['Tuesday Nights in 1980', 'Fiction', 'Two', '£21.04', 'In stock (15 available)']
# *******
# ['Tracing Numbers on a Train', 'Default', 'Three', '£41.60', 'In stock (15 available)']
# *******
# ['Throne of Glass (Throne of Glass #1)', 'Fantasy', 'Three', '£35.07', 'In stock (15 available)']
# *******
# ['Thomas Jefferson and the Tripoli Pirates: The Forgotten War That Changed American History', 'History', 'One', '£59.64', 'In stock (15 available)']
# *******
# ['Thirteen Reasons Why', 'Default', 'One', '£52.72', 'In stock (15 available)']
# *******
# ['The White Cat and the Monk: A Retelling of the Poem “Pangur Bán”', 'Childrens', 'Four', '£58.08', 'In stock (15 available)']
# *******
# ['The Wedding Dress', 'Romance', 'One', '£24.12', 'In stock (15 available)']
# *******
# ['The Vacationers', 'Fiction', 'Four', '£42.15', 'In stock (15 available)']
# *******
# ['The Third Wave: An Entrepreneur’s Vision of the Future', 'Business', 'Five', '£12.61', 'In stock (15 available)']
# *******
# ['The Stranger', 'Philosophy', 'Four', '£17.44', 'In stock (15 available)']
# *******
# ['The Shadow Hero (The Shadow Hero)', 'Sequential Art', 'One', '£33.14', 'In stock (15 available)']
# *******
# ['The Secret (The Secret #1)', 'Default', 'Four', '£27.37', 'In stock (15 available)']
# *******
# ['The Regional Office Is Under Attack!', 'Fiction', 'Five', '£51.36', 'In stock (15 available)']
# *******
# ['The Psychopath Test: A Journey Through the Madness Industry', 'Default', 'Two', '£36.00', 'In stock (15 available)']
# *******
# ['The Project', 'Science Fiction', 'One', '£10.65', 'In stock (15 available)']
# *******
# ['The Power of Now: A Guide to Spiritual Enlightenment', 'Nonfiction', 'Two', '£43.54', 'In stock (15 available)']
# *******
# ["The Omnivore's Dilemma: A Natural History of Four Meals", 'Nonfiction', 'Two', '£38.21', 'In stock (15 available)']
# *******
# ['The Nerdy Nummies Cookbook: Sweet Treats for the Geek in All of Us', 'Food and Drink', 'Five', '£37.34', 'In stock (15 available)']
# *******
# ['The Murder of Roger Ackroyd (Hercule Poirot #4)', 'Mystery', 'Four', '£44.10', 'In stock (15 available)']
# *******
# ['The Mistake (Off-Campus #2)', 'New Adult', 'Three', '£43.29', 'In stock (15 available)']
# *******
# ["The Matchmaker's Playbook (Wingmen Inc. #1)", 'New Adult', 'One', '£55.85', 'In stock (15 available)']
# *******
# ['The Love and Lemons Cookbook: An Apple-to-Zucchini Celebration of Impromptu Cooking', 'Food and Drink', 'Two', '£37.60', 'In stock (15 available)']
# *******
# ['The Long Shadow of Small Ghosts: Murder and Memory in an American City', 'Crime', 'One', '£10.97', 'In stock (15 available)']
# *******
# ['The Kite Runner', 'Default', 'Four', '£41.82', 'In stock (15 available)']
# *******
# ['The House by the Lake', 'Historical Fiction', 'One', '£36.95', 'In stock (15 available)']
# *******
# ['The Glittering Court (The Glittering Court #1)', 'Fantasy', 'One', '£44.28', 'In stock (15 available)']
# *******
# ['The Girl on the Train', 'Default', 'Two', '£55.02', 'In stock (15 available)']
# *******
# ['The Genius of Birds', 'Nonfiction', 'One', '£17.24', 'In stock (15 available)']
# *******
# ['The Emerald Mystery', 'Default', 'Two', '£23.15', 'In stock (15 available)']
# *******
# ['The Cookies & Cups Cookbook: 125+ sweet & savory recipes reminding you to Always Eat Dessert First', 'Food and Drink', 'One', '£41.25', 'In stock (15 available)']
# *******
# ["The Bridge to Consciousness: I'm Writing the Bridge Between Science and Our Old and New Beliefs.", 'Default', 'Three', '£32.00', 'In stock (15 available)']
# *******
# ["The Artist's Way: A Spiritual Path to Higher Creativity", 'Nonfiction', 'Five', '£38.49', 'In stock (15 available)']
# *******
# ['The Art of War', 'Default', 'Five', '£33.34', 'In stock (15 available)']
# *******
# ['The Argonauts', 'Autobiography', 'Two', '£10.93', 'In stock (15 available)']
# *******
# ['The 10% Entrepreneur: Live Your Startup Dream Without Quitting Your Day Job', 'Business', 'Three', '£27.55', 'In stock (15 available)']
# *******
# ['Suddenly in Love (Lake Haven #1)', 'Romance', 'Two', '£55.99', 'In stock (15 available)']
# *******
# ['Something More Than This', 'Romance', 'Four', '£16.24', 'In stock (15 available)']
# *******
# ['Soft Apocalypse', 'Science Fiction', 'Two', '£26.12', 'In stock (15 available)']
# *******
# ["So You've Been Publicly Shamed", 'Nonfiction', 'Two', '£12.23', 'In stock (15 available)']
# *******
# ['Shoe Dog: A Memoir by the Creator of NIKE', 'Business', 'Two', '£23.99', 'In stock (15 available)']
# *******
# ['Shobu Samurai, Project Aryoku (#3)', 'Add a comment', 'Three', '£29.06', 'In stock (15 available)']
# *******
# ['Secrets and Lace (Fatal Hearts #1)', 'Default', 'One', '£20.27', 'In stock (15 available)']
# *******
# ['Scarlett Epstein Hates It Here', 'Young Adult', 'Five', '£43.55', 'In stock (15 available)']
# *******
# ['Romero and Juliet: A Tragic Tale of Love and Zombies', 'Default', 'One', '£36.94', 'In stock (15 available)']
# *******
# ['Redeeming Love', 'Christian Fiction', 'Five', '£20.47', 'In stock (15 available)']
# *******
# ['Poses for Artists Volume 1 - Dynamic and Sitting Poses: An Essential Reference for Figure Drawing and the Human Form', 'Default', 'One', '£41.06', 'In stock (15 available)']
# *******
# ['Poems That Make Grown Women Cry', 'Poetry', 'Four', '£14.19', 'In stock (15 available)']
# *******
# ['Nightingale, Sing', 'Young Adult', 'One', '£38.28', 'In stock (15 available)']
# *******
# ['Night Sky with Exit Wounds', 'Poetry', 'One', '£41.05', 'In stock (15 available)']
# *******
# ['Mrs. Houdini', 'Historical Fiction', 'Five', '£30.25', 'In stock (15 available)']
# *******
# ['Modern Romance', 'Add a comment', 'Five', '£28.26', 'In stock (15 available)']
# *******
# ['Miss Peregrine’s Home for Peculiar Children (Miss Peregrine’s Peculiar Children #1)', 'Default', 'One', '£10.76', 'In stock (15 available)']
# *******
# ['Louisa: The Extraordinary Life of Mrs. Adams', 'Biography', 'Two', '£16.85', 'In stock (15 available)']
# *******
# ['Little Red', 'Childrens', 'Three', '£13.47', 'In stock (15 available)']
# *******
# ['Library of Souls (Miss Peregrine’s Peculiar Children #3)', 'Young Adult', 'Five', '£48.56', 'In stock (15 available)']
# *******
# ['Large Print Heart of the Pride', 'Default', 'Two', '£19.15', 'In stock (15 available)']
# *******
# ['I Had a Nice Time And Other Lies...: How to find love & sh*t like that', 'Womens Fiction', 'Four', '£57.36', 'In stock (15 available)']
# *******
# ['Hollow City (Miss Peregrine’s Peculiar Children #2)', 'Fantasy', 'One', '£42.98', 'In stock (15 available)']
# *******
# ['Grumbles', 'Default', 'Two', '£22.16', 'In stock (15 available)']
# *******
# ['Full Moon over Noah’s Ark: An Odyssey to Mount Ararat and Beyond', 'Travel', 'Four', '£49.43', 'In stock (15 available)']
# *******
# ['Frostbite (Vampire Academy #2)', 'Young Adult', 'Five', '£29.99', 'In stock (15 available)']
# *******
# ['Follow You Home', 'Horror', 'One', '£21.36', 'In stock (15 available)']
# *******
# ['First Steps for New Christians (Print Edition)', 'Default', 'One', '£29.00', 'In stock (15 available)']
# *******
# ['Finders Keepers (Bill Hodges Trilogy #2)', 'Fiction', 'Five', '£53.53', 'In stock (15 available)']
# *******
# ['Fables, Vol. 1: Legends in Exile (Fables #1)', 'Sequential Art', 'Four', '£41.62', 'In stock (15 available)']
# *******
# ['Eureka Trivia 6.0', 'Default', 'Four', '£54.59', 'In stock (15 available)']
# *******
# ['Drive: The Surprising Truth About What Motivates Us', 'Default', 'Four', '£34.95', 'In stock (15 available)']
# *******
# ['Done Rubbed Out (Reightman & Bailey #1)', 'Default', 'Five', '£37.72', 'In stock (15 available)']
# *******
# ['Doing It Over (Most Likely To #1)', 'Romance', 'Three', '£35.61', 'In stock (15 available)']
# *******
# ['Deliciously Ella Every Day: Quick and Easy Recipes for Gluten-Free Snacks, Packed Lunches, and Simple Meals', 'Food and Drink', 'Three', '£42.16', 'In stock (15 available)']
# *******
# ['Dark Notes', 'Erotica', 'Five', '£19.19', 'In stock (15 available)']
# *******
# ['Daring Greatly: How the Courage to Be Vulnerable Transforms the Way We Live, Love, Parent, and Lead', 'Nonfiction', 'Three', '£19.43', 'In stock (15 available)']
# *******
# ['Close to You', 'Christian Fiction', 'Four', '£49.46', 'In stock (15 available)']
# *******
# ['Chasing Heaven: What Dying Taught Me About Living', 'Spirituality', 'Two', '£37.80', 'In stock (15 available)']
# *******
# ['Big Magic: Creative Living Beyond Fear', 'Nonfiction', 'Three', '£30.80', 'In stock (15 available)']
# *******
# ['Becoming Wise: An Inquiry into the Mystery and Art of Living', 'Nonfiction', 'Two', '£27.43', 'In stock (15 available)']
# *******
# ['Beauty Restored (Riley Family Legacy Novellas #3)', 'Default', 'Two', '£11.11', 'In stock (15 available)']
# *******
# ['Batman: The Long Halloween (Batman)', 'Sequential Art', 'Two', '£36.50', 'In stock (15 available)']
# *******
# ['Batman: The Dark Knight Returns (Batman)', 'Sequential Art', 'Five', '£15.38', 'In stock (15 available)']
# *******
# ["Ayumi's Violin", 'Default', 'Two', '£15.48', 'In stock (15 available)']
# *******
# ['Anonymous', 'Default', 'Four', '£46.82', 'In stock (15 available)']
# *******
# ['Amy Meets the Saints and Sages', 'Default', 'Three', '£18.46', 'In stock (15 available)']
# *******
# ['Amid the Chaos', 'Cultural', 'One', '£36.58', 'In stock (15 available)']
# *******
# ['Amatus', 'Default', 'Five', '£50.54', 'In stock (15 available)']
# *******
# ['Agnostic: A Spirited Manifesto', 'Nonfiction', 'Five', '£12.51', 'In stock (15 available)']
# *******
# ['Zealot: The Life and Times of Jesus of Nazareth', 'History', 'Three', '£24.70', 'In stock (14 available)']
# *******
# ['You (You #1)', 'Thriller', 'Five', '£43.61', 'In stock (14 available)']
# *******
# ['Wonder Woman: Earth One, Volume One (Wonder Woman: Earth One #1)', 'Sequential Art', 'Four', '£37.34', 'In stock (14 available)']
# *******
# ['Wild Swans', 'Young Adult', 'Two', '£14.36', 'In stock (14 available)']
# *******
# ['Why the Right Went Wrong: Conservatism--From Goldwater to the Tea Party and Beyond', 'Politics', 'Four', '£52.65', 'In stock (14 available)']
# *******
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 24
#      21 book_url = book.find('a')['href']
#      22 book_url = 'https://books.toscrape.com/catalogue/' + book_url
# ---> 24 book_response = requests.get(book_url)
#      25 book_soup = BeautifulSoup(book_response.content, "html.parser")
#      27 title = book_soup.find('h1').text
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/adapters.py:487, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     484     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     486 try:
# --> 487     resp = conn.urlopen(
#     488         method=request.method,
#     489         url=url,
#     490         body=request.body,
#     491         headers=request.headers,
#     492         redirect=False,
#     493         assert_same_host=False,
#     494         preload_content=False,
#     495         decode_content=False,
#     496         retries=self.max_retries,
#     497         timeout=timeout,
#     498         chunked=chunked,
#     499     )
#     501 except (ProtocolError, OSError) as err:
#     502     raise ConnectionError(err, request=request)
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     711     self._prepare_proxy(conn)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#     728 response_conn = conn if not release_conn else None
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:403, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     401 # Trigger any extra validation we need to do.
#     402 try:
# --> 403     self._validate_conn(conn)
#     404 except (SocketTimeout, BaseSSLError) as e:
#     405     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#     406     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:1053, in HTTPSConnectionPool._validate_conn(self, conn)
#    1051 # Force connect early to allow us to validate the connection.
#    1052 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1053     conn.connect()
#    1055 if not conn.is_verified:
#    1056     warnings.warn(
#    1057         (
#    1058             "Unverified HTTPS request is being made to host '%s'. "
#    (...)
#    1063         InsecureRequestWarning,
#    1064     )
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connection.py:419, in HTTPSConnection.connect(self)
#     410 if (
#     411     not self.ca_certs
#     412     and not self.ca_cert_dir
#    (...)
#     415     and hasattr(context, "load_default_certs")
#     416 ):
#     417     context.load_default_certs()
# --> 419 self.sock = ssl_wrap_socket(
#     420     sock=conn,
#     421     keyfile=self.key_file,
#     422     certfile=self.cert_file,
#     423     key_password=self.key_password,
#     424     ca_certs=self.ca_certs,
#     425     ca_cert_dir=self.ca_cert_dir,
#     426     ca_cert_data=self.ca_cert_data,
#     427     server_hostname=server_hostname,
#     428     ssl_context=context,
#     429     tls_in_tls=tls_in_tls,
#     430 )
#     432 # If we're using all defaults and the connection
#     433 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     434 # for the host.
#     435 if (
#     436     default_ssl_context
#     437     and self.ssl_version is None
#     438     and hasattr(self.sock, "version")
#     439     and self.sock.version() in {"TLSv1", "TLSv1.1"}
#     440 ):
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/util/ssl_.py:449, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     437     warnings.warn(
#     438         "An HTTPS request has been made, but the SNI (Server Name "
#     439         "Indication) extension to TLS is not available on this platform. "
#    (...)
#     445         SNIMissingWarning,
#     446     )
#     448 if send_sni:
# --> 449     ssl_sock = _ssl_wrap_socket_impl(
#     450         sock, context, tls_in_tls, server_hostname=server_hostname
#     451     )
#     452 else:
#     453     ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls)
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/util/ssl_.py:493, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     490     return SSLTransport(sock, ssl_context, server_hostname)
#     492 if server_hostname:
# --> 493     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494 else:
#     495     return ssl_context.wrap_socket(sock)
#
# File ~/anaconda3/lib/python3.11/ssl.py:517, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     511 def wrap_socket(self, sock, server_side=False,
#     512                 do_handshake_on_connect=True,
#     513                 suppress_ragged_eofs=True,
#     514                 server_hostname=None, session=None):
#     515     # SSLSocket class handles server_hostname encoding before it calls
#     516     # ctx._wrap_socket()
# --> 517     return self.sslsocket_class._create(
#     518         sock=sock,
#     519         server_side=server_side,
#     520         do_handshake_on_connect=do_handshake_on_connect,
#     521         suppress_ragged_eofs=suppress_ragged_eofs,
#     522         server_hostname=server_hostname,
#     523         context=self,
#     524         session=session
#     525     )
#
# File ~/anaconda3/lib/python3.11/ssl.py:1075, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1072         if timeout == 0.0:
#    1073             # non-blocking
#    1074             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1075         self.do_handshake()
#    1076 except (OSError, ValueError):
#    1077     self.close()
#
# File ~/anaconda3/lib/python3.11/ssl.py:1346, in SSLSocket.do_handshake(self, block)
#    1344     if timeout == 0.0 and block:
#    1345         self.settimeout(None)
# -> 1346     self._sslobj.do_handshake()
#    1347 finally:
#    1348     self.settimeout(timeout)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Export the Data

# %%
df = pd.DataFrame(books_data, columns=["Title","Category","Rating","Price","Availability"])

# %%
#save to csv
df.to_csv("books_scraped.csv",index=False)
print('Data Saved to books_scraped.csv')
# Out:
# Data Saved to books_scraped.csv
